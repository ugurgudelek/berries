# %%
# %load_ext autoreload
# %autoreload 2

# %%
import multiprocessing
from functools import reduce
from dataset import WearData
from pathlib import Path
import pandas as pd
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
if __name__ == '__main__':
    wear_data = WearData.read_and_merge()
    wear_data.save()

# %%
wear_data.tdms_data.loc[:, ['wear_len']].resample('1s').mean().plot()

# %%
wear_data.tdms_data['ix'] = range(0, wear_data.tdms_data.shape[0])
data = wear_data.tdms_data.loc[:, ['acc', 'ix']].iloc[1000*60*82+1000*15:1000*60*(80+3)-1000*10]
data['acc'].plot()

# %%
wear_data.tdms_data.shape[0]*0.8

# %%
data = wear_data.tdms_data.loc[:, ['acc']].resample('1S').std().iloc[60*80:60*(80+1)].plot()

# %%
wear_data.tdms_data.loc[:, ['acc']].plot()

# %%
wear_data.tdms_data.loc[:, ['wear_len', 'cut_len']].plot(y='wear_len', x='cut_len')

# %%
# wear_data.tdms_data.loc[:, ['wear_len', 'time']].plot(y='wear_len', x='time')
c = wear_data.tdms_data['cut_len'].values
w = wear_data.tdms_data['wear_len'].values

c_ = wear_data.label_df['cut_len'].values
w_ = wear_data.label_df['wear_len'].values

# %%
plt.plot(c, w)
plt.plot(c_,w_, '.')
