# %%
import pandas as pd
import os

# %%
df2000 = pd.read_csv("dataholder_2000.csv", index_col=0)

# %%
df2001 = pd.read_csv("dataholder_2001.csv", index_col=0)

# %%
df2000.append(df2001, ignore_index=True)
# Out:
#              0         1         2         3         4         5         6  \
# 0     1.028144  1.170187  1.286510 -1.543310 -1.484914 -1.437555 -1.691508
# 1     0.782266  0.635844  0.613666 -1.253851 -1.205585 -1.163817 -1.618313
# 2     0.599222  0.610523  0.661145 -2.264798 -2.110202 -1.987110 -3.538897
# 3     1.846375  1.992617  2.047292 -2.449167 -2.310358 -2.199706 -2.012927
# 4     0.093797  0.027102  0.013521 -0.767391 -0.698835 -0.653558 -1.295427
# 5     1.047003  0.730313  0.696770 -1.334016 -1.315698 -1.302768 -1.224061
# 6     0.635146  0.534904  0.548933 -1.241507 -1.158673 -1.089709 -1.878080
# 7     1.343182  1.085069  0.852864 -1.319639 -1.427601 -1.526051 -0.283821
# 8     0.977007  0.661013  0.684910 -0.762045 -0.691705 -0.664530 -1.183201
# 9    -0.021189 -0.156267 -0.151025 -1.126849 -1.117679 -1.110172 -1.062632
# 10    1.188492  1.178079  1.191843 -1.399414 -1.349357 -1.304862 -1.861153
# ...

# %%
df = pd.DataFrame()
for filename in os.listdir():
    if filename.split('.')[-1] == 'csv':
        df = df.append(pd.read_csv(filename, index_col=0))
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0      1.028144  1.170187  1.286510 -1.543310 -1.484914 -1.437555 -1.691508
# 1      0.782266  0.635844  0.613666 -1.253851 -1.205585 -1.163817 -1.618313
# 2      0.599222  0.610523  0.661145 -2.264798 -2.110202 -1.987110 -3.538897
# 3      1.846375  1.992617  2.047292 -2.449167 -2.310358 -2.199706 -2.012927
# 4      0.093797  0.027102  0.013521 -0.767391 -0.698835 -0.653558 -1.295427
# 5      1.047003  0.730313  0.696770 -1.334016 -1.315698 -1.302768 -1.224061
# 6      0.635146  0.534904  0.548933 -1.241507 -1.158673 -1.089709 -1.878080
# 7      1.343182  1.085069  0.852864 -1.319639 -1.427601 -1.526051 -0.283821
# 8      0.977007  0.661013  0.684910 -0.762045 -0.691705 -0.664530 -1.183201
# 9     -0.021189 -0.156267 -0.151025 -1.126849 -1.117679 -1.110172 -1.062632
# 10     1.188492  1.178079  1.191843 -1.399414 -1.349357 -1.304862 -1.861153
# ...

# %%
df.to_csv('dataholder.csv',index=False)

# %%
df.to_hdf('dataholder.h5py',key='df')

# %%
a = pd.read_hdf('dataholder.h5py', key='df')

# %%
a
# Out:
#                0         1        10       100       101       102       103  \
# 0            NaN  1.170187 -1.243305 -0.903178 -0.657303 -0.638543 -0.615087
# 1            NaN  0.635844 -1.208565 -0.652343 -0.366536  0.058220  0.403852
# 2            NaN  0.610523 -2.627184 -0.842300 -0.012545  0.906766  1.551816
# 3            NaN  1.992617 -0.474072 -1.272271 -1.251291 -1.055505 -0.810687
# 4            NaN  0.027102  0.232011  0.993169  1.539801  1.612738  1.485426
# 5            NaN  0.730313 -2.433353 -0.730334 -0.571867 -0.336331  0.088864
# 6            NaN  0.534904  0.219695 -0.247887  0.679739  1.210816  1.510910
# 7            NaN  1.085069  0.335576 -1.321287 -1.177830 -1.294566 -1.291441
# 8            NaN  0.661013 -0.908588 -0.182768  0.914164  1.086494  0.985806
# 9            NaN -0.156267 -1.692011  0.218999  0.918534  1.476992  1.523477
# 10           NaN  1.178079 -0.280458 -0.607996 -0.138946  0.300935  0.892397
# ...
