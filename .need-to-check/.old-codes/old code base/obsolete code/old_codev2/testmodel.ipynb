# %%
import keras
import pandas as pd
import numpy as np
from dataset import Dataset
# Out:
# Using TensorFlow backend.

# %%
dataset = Dataset()
dataset.load(path="../input/dataholder/dataholder.h5py")
dataset.train_test_split('2014-12-31')
dataset.transformXy()

# %%
model = keras.models.load_model("../model/7_model.h5py")

# %%
# Out:
# 0.49988235294117644
