# %%
import pandas as pd
from preprocessing import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = get_last_saved_data()
history = pd.read_pickle("../result/history.pickle")

# %%
history.keys()
# Out:
# dict_keys(['acc', 'loss', 'prediction'])

# %%
predictions = np.array(history['prediction'])
predictions = predictions.reshape(predictions.shape[0])
predictions = pd.DataFrame(predictions)

test_labels = data["test_labels"].ix[:,0]
test_names  = data['test_names'].ix[:,0]
test_dates = data['test_dates'].ix[:,0]

# %%
predictions.hist(bins=100)
test_labels.hist(bins=100)

# %%
result = pd.DataFrame()
result['name'] = test_names
result['date'] = test_dates
result['label'] = test_labels
result['prediction'] = predictions

# %%
result.head()
# Out:
#   name        date     label  prediction
# 0  spy  2015-03-24 -0.898692   -0.236648
# 1  spy  2015-03-25 -0.233740   -0.846313
# 2  spy  2015-03-26  0.225048   -0.229367
# 3  spy  2015-03-27  0.839650    0.356417
# 4  spy  2015-03-30 -0.703375    0.868107

# %%
result['disc_label'] = result.label.apply(lambda x: int((x+1)*(1.5)))
result['disc_pred'] = result.prediction.apply(lambda x: int((x+1)*(1.5)))

# %%
result.head(n=50)
# Out:
#    name        date     label  prediction  disc_label  disc_pred
# 0   spy  2015-03-24 -0.898692   -0.236648           0          1
# 1   spy  2015-03-25 -0.233740   -0.846313           1          0
# 2   spy  2015-03-26  0.225048   -0.229367           1          1
# 3   spy  2015-03-27  0.839650    0.356417           2          2
# 4   spy  2015-03-30 -0.703375    0.868107           0          2
# 5   spy  2015-03-31 -0.339592   -0.087195           0          1
# 6   spy  2015-04-01  0.344991   -0.210866           2          1
# 7   spy  2015-04-02  0.587159    0.457581           2          2
# 8   spy  2015-04-06 -0.258630    0.529719           1          2
# 9   spy  2015-04-07  0.325429   -0.025991           1          1
# 10  spy  2015-04-08  0.415591    0.212838           2          1
# 11  spy  2015-04-09  0.497302    0.186254           2          1
# 12  spy  2015-04-10 -0.423784    0.400842           0          2
# 13  spy  2015-04-13  0.189005    0.004410           1          1
# 14  spy  2015-04-14  0.420837    0.031973           2          1
# 15  spy  2015-04-15 -0.028505    0.576148           1          2
# 16  spy  2015-04-16 -0.817871    0.020203           0          1
# 17  spy  2015-04-17  0.722894   -0.119329           2          1
# 18  spy  2015-04-20 -0.118572    0.397651           1          2
# 19  spy  2015-04-21  0.455337    0.157313           2          1
# 20  spy  2015-04-22  0.246447    0.460140           1          2
# 21  spy  2015-04-23  0.227974    0.208714           1          1
# 22  spy  2015-04-24 -0.393370    0.143278           0          1
# 23  spy  2015-04-27  0.307591   -0.210600           1          1
# 24  spy  2015-04-28 -0.389715   -0.065025           0          1
# 25  spy  2015-04-29 -0.762450   -0.274208           0          1
# 26  spy  2015-04-30  0.794730   -0.196302           2          1
# 27  spy  2015-05-01  0.277285    0.515407           1          2
# 28  spy  2015-05-04 -0.816152    0.397850           0          2
# 29  spy  2015-05-05 -0.389898   -0.195630           0          1
# 30  spy  2015-05-06  0.379060   -0.116592           2          1
# 31  spy  2015-05-07  0.865938    0.033983           2          1
# 32  spy  2015-05-08 -0.447841    0.170190           0          1
# 33  spy  2015-05-11 -0.286177   -0.039351           1          1
# 34  spy  2015-05-12  0.019047    0.004570           1          1
# 35  spy  2015-05-13  0.778975    0.133679           2          1
# 36  spy  2015-05-14  0.107961    0.125481           1          1
# 37  spy  2015-05-15  0.301052    0.021082           1          1
# 38  spy  2015-05-18 -0.032837    0.181688           1          1
# 39  spy  2015-05-19 -0.070296    0.129296           1          1
# 40  spy  2015-05-20  0.283279   -0.201540           1          1
# 41  spy  2015-05-21 -0.234434    0.112758           1          1
# 42  spy  2015-05-22 -0.791400    0.051372           0          1
# 43  spy  2015-05-26  0.739428    0.080313           2          1
# 44  spy  2015-05-27 -0.112359    0.191106           1          1
# 45  spy  2015-05-28 -0.552028   -0.051687           0          1
# 46  spy  2015-05-29  0.200887   -0.051791           1          1
# 47  spy  2015-06-01 -0.098933    0.213453           1          1
# 48  spy  2015-06-02  0.258920   -0.025981           1          1
# 49  spy  2015-06-03 -0.688269   -0.049008           0          1

# %%
real_buy = result[result.disc_label == 2]
real_sell = result[result.disc_label == 0]

total_buy_sgn_count = real_buy.count()
true_buy_sgn_count = np.array([real_buy.disc_pred >= 2]).sum() #1307
wrong_buy_sgn_count = np.array([real_buy.disc_pred == 0]).sum()  #37 / 2564

true_sell_sgn_count = np.array([real_sell.disc_pred == 0]).sum() #1241
wrong_sell_sgn_count = np.array([real_sell.disc_pred >= 2]).sum() #55 / 2389

# %%
(real_buy.name.count(), true_buy_sgn_count,wrong_buy_sgn_count),(real_sell.name.count(),true_sell_sgn_count,wrong_sell_sgn_count)
# Out:
# ((2564, 1267, 49), (2389, 1188, 62))

# %%
(np.array([result.disc_pred == result.disc_label]).sum(),result.shape[0])
# Out:
# (4076, 7139)

# %%
ratio = 0.38
ll = result.label[result.label < -ratio]
ml = result.label[np.logical_and(result.label >= -ratio,result.label <= ratio)]
rl = result.label[result.label > ratio]

lp = result.prediction[result.prediction < -ratio]
mp = result.prediction[np.logical_and(result.prediction >= -ratio,result.prediction <= ratio)]
rp = result.prediction[result.prediction > ratio]

# %%
ll.hist()
ml.hist()
rl.hist()
lp.hist()
mp.hist()
rp.hist()

# %% [raw]
# import numpy
# import pandas
# from  matplotlib import pyplot
# import seaborn
# seaborn.set(style='ticks')
#
# numpy.random.seed(0)
# N = 37
# _genders= ['Female', 'Male', 'Non-binary', 'No Response']
# df = pandas.DataFrame({
#     'Height (cm)': numpy.random.uniform(low=130, high=200, size=N),
#     'Weight (kg)': numpy.random.uniform(low=30, high=100, size=N),
#     'Gender': numpy.random.choice(_genders, size=N)
# })
#
# fg = seaborn.FacetGrid(data=df, hue='Gender', hue_order=_genders, aspect=1.61)
# fg.map(pyplot.scatter, 'Weight (kg)', 'Height (cm)').add_legend()

# %%
result['index']=np.array(result.index)

# %%
result['p_experimental'] = result.prediction.apply(lambda x:x**5)

# %%
result.describe()
# Out:
#              label   prediction   disc_label    disc_pred        index  \
# count  7139.000000  7139.000000  7139.000000  7139.000000  7139.000000
# mean      0.011905     0.015245     1.024513     1.028295  3569.000000
# std       0.627429     0.400399     0.832641     0.667070  2060.996118
# min      -1.000000    -1.506173     0.000000     0.000000     0.000000
# 25%      -0.546193    -0.265633     0.000000     1.000000  1784.500000
# 50%       0.022343     0.030174     1.000000     1.000000  3569.000000
# 75%       0.563949     0.311050     2.000000     1.000000  5353.500000
# max       0.999993     1.250629     2.000000     3.000000  7138.000000
#
#        p_experimental
# count    7.139000e+03
# mean    -6.489320e-03
# std      2.210903e-01
# min     -7.751308e+00
# 25%     -1.322547e-03
# 50%      2.501250e-08
# 75%      2.911748e-03
# max      3.059445e+00

# %%
result_wo_hold = result[~np.logical_and(result.label >= -ratio,result.label <= ratio)]

# %% [markdown]
# Lets look at the false negative and false positive.
# Below I take the power of 5 for predictions. Then create a colormap with respect to true label values.
# Here are some results which i think nice

# %%
import seaborn
fg = seaborn.FacetGrid(data=result, hue='disc_label',aspect=1, size =10)
fg.map(plt.scatter,'index','p_experimental', alpha=1).add_legend()

# %%
palette = seaborn.color_palette(palette="Set2")
fg = seaborn.FacetGrid(data=result, hue='disc_label',aspect=1, size =10, palette=palette)
fg.map(plt.scatter,'index','prediction', alpha=0.9).add_legend()

# %%
import seaborn
fg = seaborn.FacetGrid(data=result_wo_hold, hue='disc_label',aspect=1, size =10)
fg.map(plt.scatter,'index','p_experimental', alpha=1).add_legend()

# %%
palette = seaborn.color_palette(palette="Set2")
fg = seaborn.FacetGrid(data=result_wo_hold, hue='disc_label',aspect=1, size =10, palette=palette)
fg.map(plt.scatter,'index','prediction', alpha=0.9).add_legend()
