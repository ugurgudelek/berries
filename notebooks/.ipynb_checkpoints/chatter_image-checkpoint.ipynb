# %%
from dataset.chatter_image import ChatterImage
from model.cnn import CNN


from trainer.classifier import ClassifierTrainer
import torch
import numpy as np
import os
from torchvision import transforms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fd1fe0beaf9> in <module>
# ----> 1 from dataset.chatter_image import ChatterImage
#       2 from model.cnn import CNN
#       3
#       4
#       5 from trainer.classifier import ClassifierTrainer
#
# ModuleNotFoundError: No module named 'dataset'
