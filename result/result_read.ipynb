# %%
import numpy as np
import cpi

# %%
with open("buy_sell_model_regr_2017_07_12 19_00_45_963287", 'rb') as f:
    a = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-1f3f61743bdf> in <module>()
#       1 with open("buy_sell_model_regr_2017_07_12 19_00_45_963287", 'rb') as f:
# ----> 2     a = pickle.load(f)
#
# ImportError: No module named 'pandas.core.indexes'
