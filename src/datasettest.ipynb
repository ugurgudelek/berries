# %%
from dataset import Dataset
import pandas as pd
# import cnn
# Out:
# Using TensorFlow backend.

# %%
dataset = Dataset()
dataset.load(path="../input/dataholder/dataholder.h5py")

# %%
params = {"input_w": 28, "input_h": 28, "num_classes": 1, "batch_size": 10, "epochs": 100}
cnnengine = cnn.CNNEngine(params=params,model_save_path='../model', run_number='7')

# %%
cnnengine.train_direct(dataset.X, dataset.y)

# %%
dataset.dataframe['date']
# Out:
# 0        2000-04-06
# 1        2000-04-06
# 2        2000-04-06
# 3        2000-04-06
# 4        2000-04-06
# 5        2000-04-06
# 6        2000-04-06
# 7        2000-04-06
# 8        2000-04-06
# 9        2000-04-06
# 10       2000-04-06
# 11       2000-04-06
# 12       2000-04-06
# 13       2000-04-06
# 14       2000-04-06
# 15       2000-04-06
# 16       2000-04-06
# 17       2000-04-07
# 18       2000-04-07
# 19       2000-04-07
# 20       2000-04-07
# 21       2000-04-07
# 22       2000-04-07
# 23       2000-04-07
# 24       2000-04-07
# 25       2000-04-07
# 26       2000-04-07
# 27       2000-04-07
# 28       2000-04-07
# 29       2000-04-07
#             ...
# 71139    2016-12-22
# 71140    2016-12-22
# 71141    2016-12-22
# 71142    2016-12-22
# 71143    2016-12-22
# 71144    2016-12-22
# 71145    2016-12-22
# 71146    2016-12-22
# 71147    2016-12-22
# 71148    2016-12-22
# 71149    2016-12-22
# 71150    2016-12-22
# 71151    2016-12-22
# 71152    2016-12-23
# 71153    2016-12-23
# 71154    2016-12-23
# 71155    2016-12-23
# 71156    2016-12-23
# 71157    2016-12-23
# 71158    2016-12-23
# 71159    2016-12-23
# 71160    2016-12-23
# 71161    2016-12-23
# 71162    2016-12-23
# 71163    2016-12-23
# 71164    2016-12-23
# 71165    2016-12-23
# 71166    2016-12-23
# 71167    2016-12-23
# 71168    2016-12-23
# Name: date, Length: 71169, dtype: object
