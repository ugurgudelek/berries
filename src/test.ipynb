# %%
import metric
import pandas as pd

# %%
closes = [44.34,44.09,44.15,43.61,44.33,
         44.83,45.10,45.42,45.84,46.08,
         45.89,46.03,45.61,46.28,46.28,
         46.00,46.03,46.41,46.22,45.64,
         46.21,46.25,45.71,46.45,45.78,
         45.35,44.03,44.18,44.22,44.57,
         43.42,42.66,43.13]
dates = ['somedate'] * len(closes)
series = [{'data':close, 'date':date} for (close,date) in zip(closes, dates)]

# %%
rsi = metric.RSI(14)
for row in series:
    rsi.feed(row)

# %%
rsi.containers_to_dataframe().apply(lambda x: round(x,2))
# Out:
#      data   RSIs   RSs  average_gains  average_losses
# 0   44.34    NaN   NaN           0.00            0.00
# 1   44.09    NaN   NaN           0.00            0.02
# 2   44.15    NaN   NaN           0.00            0.02
# 3   43.61    NaN   NaN           0.00            0.06
# 4   44.33    NaN   NaN           0.06            0.06
# 5   44.83    NaN   NaN           0.09            0.06
# 6   45.10    NaN   NaN           0.11            0.06
# 7   45.42    NaN   NaN           0.13            0.06
# 8   45.84    NaN   NaN           0.16            0.06
# 9   46.08    NaN   NaN           0.18            0.06
# 10  45.89    NaN   NaN           0.18            0.07
# 11  46.03    NaN   NaN           0.19            0.07
# 12  45.61    NaN   NaN           0.19            0.10
# 13  46.28    NaN   NaN           0.24            0.10
# 14  46.28  70.46  2.39           0.22            0.09
# 15  46.00  65.95  1.94           0.21            0.11
# ...

# %%
rsi.gains
# Out:
# [0.0, 0.5700000000000003, 0.03999999999999915, 0.0, 0.740000000000002, 0.0, 0.0, 0.0, 0.14999999999999858, 0.03999999999999915, 0.3500000000000014, 0.0, 0.0, 0.47000000000000597]

# %%
rsi.losses
# Out:
# [0.5799999999999983, 0.0, 0.0, 0.5399999999999991, 0.0, 0.6700000000000017, 0.4299999999999997, 1.3200000000000003, 0.0, 0.0, 0.0, 1.1499999999999986, 0.7600000000000051, 0.0]

# %%
rsi.RSI
# Out:
# 37.34747954444208

# %%
rsi.__dict__
# Out:
# {'RS': 0.5961049814577567,
#  'RSI': 37.34747954444208,
#  'RSIs': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   70.46413502109704,
#   65.94621118302682,
#   66.19629351427443,
#   69.2742797156474,
#   66.0365441800516,
#   57.24147525888346,
#   62.52398022805575,
#   62.87064082003635,
#   55.41784685866839,
#   62.05586621087375,
#   54.188768843853,
#   49.823192646587586,
#   39.34451188535799,
#   40.8664979196962,
#   41.28956504439905,
#   44.99764987870061,
#   36.77825318775952,
#   32.54706470699138,
#   37.34747954444208],
#  'RSs': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   2.3857142857142852,
#   1.936530808288731,
#   1.958255481310235,
#   2.254602303039452,
#   1.9443411333090888,
#   1.3387149253968562,
#   1.668373018493901,
#   1.6932864506307894,
#   1.2430500313205182,
# ...

# %%
rsi2 = metric.RSI(14)

# %%
rsi2.feed(series[6])
rsi2
# Out:
# RSI:None
# RS:None
# average_gain:0.0
# average_loss:0.0
# gains:[0.0]
# losses:[-0.0]
# period:14
# data:[45.1]
# RSIs:[None]
# RSs:[None]
# average_gains:[0.0]
# average_losses:[0.0]
